# %%
from nltk.tokenize import sent_tokenize
import re
import statistics
import os
import glob
import csv
from google.colab import drive
from google.colab import auth

# %%
auth.authenticate_user()

# !fusermount -u /content/drive  # Unmount first
drive.mount('/content/drive', force_remount=True)

# Check if the mount was successful
if os.path.exists('/content/drive/MyDrive'):
  print("Google Drive mounted successfully!")
else:
  print("Failed to mount Google Drive. Please check authentication and network.")
# Out:
# fusermount: failed to unmount /content/drive: No such file or directory
# Mounted at /content/drive
# Google Drive mounted successfully!

# %% [markdown]
# The cell below is a sanity check to ensure we are able to access the folder/directory where our corpus input and output folders are. If you put in the path to the folder correctly, you should see the files in your folder.

# %%
drive_path = '/content/drive/My Drive/Where In The World'

# Check if the "Shared with me" directory exists
if os.path.exists(drive_path):
    print("Listing directories in google drive path:")
    print(os.listdir(drive_path))
# Out:
# Listing directories in google drive path:
# ['Segmentation', 'HuggingFace NER', 'Topic modeling Parti Pris', 'Summer 2024 Version - QuebecNationalLibraryScraper.ipynb', 'metadata', 'corpus', 'Em NER', 'Magazines.gsheet', "Em's research notes.gdoc"]

# %% [markdown]
# Make sure to change the directory_path and output_directory_path to the correct path on your computer. Check using the above cell that you are accessing the correct input/output folder, especially the output folder

# %%
directory_path = '/content/drive/My Drive/Where In The World/Segmentation/Additional files (temp)/'
output_directory_path = '/content/drive/My Drive/Where In The World/Segmentation OUTPUT/'

# CREATE OUTPUT DIRECTORY IF IT DOESN'T EXIST
if not os.path.exists(output_directory_path):
  os.makedirs(output_directory_path)

# CHECK INPUT PATH IS VALID
if os.path.exists(directory_path):
  print(f"Directory exists: {directory_path}")
  print("Contents of the directory:")
  print(os.listdir(directory_path))
else:
  print(f"Directory does not exist: {directory_path}")
# Out:
# Directory exists: /content/drive/My Drive/Where In The World/Segmentation/Additional files (temp)/
# Contents of the directory:
# ['2224873.txt', '2224874.txt', '2224875.txt', '2224876.txt', '2224877.txt', '2224878.txt', '2224879.txt', '2224880.txt', '2225521.txt', '2225522.txt', '2225523.txt', '2225524.txt', '2225525.txt', '2225526.txt', '2225527.txt', '2225528.txt', '2225529.txt', '2225530.txt', '2225531.txt', '2225532.txt', '2225533.txt', '2225534.txt', '2225535.txt', '2225536.txt', '2225537.txt', '2225539.txt', '2225540.txt', '2225541.txt', '2225542.txt', '2225544.txt', '2225545.txt', '2225546.txt', '2225547.txt', '2225548.txt', '2225549.txt', '2225550.txt', '2225551.txt', '2225552.txt', '2225553.txt', '2225556.txt', '2225557.txt', '2225558.txt', '2225559.txt', '2225560.txt', '2225561.txt', '2225562.txt', '2225924.txt', '2225925.txt', '2225926.txt', '2225927.txt', '2225928.txt', '2225929.txt', '2225930.txt', '2225931.txt', '2225932.txt', '2225933.txt', '2225934.txt', '2225935.txt', '2225936.txt', '2225937.txt', '2225938.txt', '2225939.txt', '2225940.txt', '2225961.txt', '2225962.txt', '2225963.txt', '2225964.txt', '2225965.txt', '2225966.txt', '2225967.txt', '2225968.txt', '2225969.txt', '2225970.txt', '2225971.txt', '2225972.txt', '2225973.txt', '2225974.txt', '2225975.txt', '2225976.txt', '2225977.txt', '2225978.txt', '2225979.txt', '2225980.txt', '2225981.txt', '2225982.txt', '2225983.txt', '2225984.txt', '2225985.txt', '2225986.txt', '2225987.txt', '2225988.txt', '2225989.txt', '2225990.txt', '2225991.txt', '2225992.txt', '2225993.txt', '2225994.txt', '2225995.txt', '2225996.txt', '2225997.txt', '2225998.txt', '2225999.txt', '2226000.txt', '2226001.txt', '2226002.txt', '2226003.txt', '2226004.txt', '2226005.txt', '2226006.txt', '2226007.txt', '2226008.txt', '2226009.txt', '2226010.txt', '2226011.txt', '2226012.txt', '2226013.txt', '2226014.txt', '2226015.txt', '2226016.txt', '2226017.txt', '2226018.txt', '2226019.txt', '2226020.txt', '2226021.txt', '2226022.txt', '2226023.txt', '2226024.txt', '2226025.txt', '2226026.txt', '2226027.txt', '2226028.txt', '2226029.txt', '2226030.txt', '2226031.txt', '2226032.txt', '2226033.txt', '2226034.txt', '2226035.txt', '2632206.txt', '2632207.txt', '2632208.txt', '2632210.txt', '2632211.txt', '2632212.txt', '2632213.txt', '2632214.txt', '2632215.txt', '2632216.txt', '2632217.txt', '2632218.txt', '2632219.txt', '2632220.txt', '2632221.txt', '2632222.txt', '2632223.txt', '2632224.txt', '2632225.txt', '2632226.txt', '2632227.txt', '2632228.txt', '2632229.txt', '2632230.txt', '2632231.txt', '2632232.txt', '2632233.txt', '2632234.txt', '2632235.txt', '2632236.txt', '2632237.txt', '2632238.txt', '2632239.txt', '2632240.txt', '2632241.txt', '2632242.txt', '2632243.txt', '2632244.txt', '2632245.txt', '2632246.txt', '2632247.txt', '2632248.txt', '2632249.txt', '2632250.txt', '2632251.txt', '2632252.txt', '2632253.txt', '2632254.txt', '2632255.txt', '2632256.txt', '2632257.txt', '2632258.txt', '2632259.txt', '2632260.txt', '2632261.txt', '2632262.txt', '2632263.txt', '2632264.txt', '2632265.txt', '2632266.txt', '2632267.txt', '2632268.txt', '2632269.txt', '2632270.txt', '2632271.txt', '2632272.txt', '2632273.txt', '2632274.txt', '2632275.txt', '2225538.txt', '2225543.txt', '2225554.txt', '2225555.txt', '2632209.txt']

# %%
# CLEAN PARAGRAPHS
def clean_paragraph(paragraph):
  paragraph = paragraph.strip()

  # Remove paragraphs with special characters not in valid punctuation
  if re.search(r'[^\w\s.,!?\'"-<>]', paragraph):
    return None

  # remove paras with multiple consecutive literal spaces
  if re.search(r'\s{2,}', paragraph):
    return None

  return paragraph

# %%
# MERGE INCORRECTLY SPLIT PARAGRAPHS
def merge_paragraphs(paragraphs):
  merged_paragraphs = []
  buffer = ""

  for i, paragraph in enumerate(paragraphs):
    paragraph = paragraph.strip()

    # check if we should merge the current paragraph with the buffer
    if buffer and not buffer.endswith(('.', '?', '!', '"', "'", '”', '’')) and paragraph and paragraph[0].islower():
      buffer += " " + paragraph
    else:
      if buffer:
        merged_paragraphs.append(buffer)
      buffer = paragraph

  # append the last buffered paragraph if exists
  if buffer:
    merged_paragraphs.append(buffer)

  return merged_paragraphs

# %%
# GET LIST OF FILES IN DIRECTORY
file_list = glob.glob(os.path.join(directory_path, '*.txt'))

for file_path in file_list:
  with open(file_path, 'r') as f:
    text = f.read()

    # SPLIT INTO PARAGRAPHS
    paragraphs = text.split('\n')

    # MERGE INCORRECTLY SPLIT PARAGRAPHS
    merged_paragraphs = merge_paragraphs(paragraphs)

    # CLEAN THE PARAGRAPHS
    cleaned_paragraphs = [clean_paragraph(paragraph) for paragraph in merged_paragraphs]
    cleaned_paragraphs = [paragraph for paragraph in cleaned_paragraphs if paragraph is not None]

    # FILTER FOR LENGTH > MEAN
    paragraph_lengths = [len(paragraph) for paragraph in cleaned_paragraphs]
    mean_paragraph_length = statistics.mean(paragraph_lengths)
    filtered_paragraphs_mean = [paragraph for paragraph in cleaned_paragraphs if len(paragraph) >= mean_paragraph_length]

    # SAVE OUTPUT TO CSV FILE
    file_name = os.path.basename(file_path).replace('.txt', '.csv')
    output_file_path = os.path.join(output_directory_path, file_name)

    with open(output_file_path, 'w', newline='') as csvfile:
      writer = csv.writer(csvfile)
      for paragraph in filtered_paragraphs_mean:
        writer.writerow([paragraph])

    print(f"Filtered content saved to: {output_file_path}")
# Out:
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224873.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224874.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224875.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224876.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224877.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224878.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224879.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2224880.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225521.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225522.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225523.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225524.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225525.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225526.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225527.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225528.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225529.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225530.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225531.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225532.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225533.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225534.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225535.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225536.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225537.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225539.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225540.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225541.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225542.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225544.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225545.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225546.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225547.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225548.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225549.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225550.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225551.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225552.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225553.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225556.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225557.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225558.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225559.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225560.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225561.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225562.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225924.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225925.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225926.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225927.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225928.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225929.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225930.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225931.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225932.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225933.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225934.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225935.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225936.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225937.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225938.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225939.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225940.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225961.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225962.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225963.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225964.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225965.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225966.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225967.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225968.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225969.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225970.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225971.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225972.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225973.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225974.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225975.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225976.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225977.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225978.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225979.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225980.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225981.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225982.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225983.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225984.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225985.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225986.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225987.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225988.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225989.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225990.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225991.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225992.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225993.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225994.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225995.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225996.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225997.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225998.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225999.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226000.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226001.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226002.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226003.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226004.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226005.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226006.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226007.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226008.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226009.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226010.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226011.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226012.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226013.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226014.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226015.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226016.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226017.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226018.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226019.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226020.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226021.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226022.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226023.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226024.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226025.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226026.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226027.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226028.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226029.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226030.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226031.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226032.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226033.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226034.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2226035.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632206.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632207.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632208.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632210.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632211.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632212.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632213.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632214.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632215.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632216.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632217.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632218.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632219.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632220.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632221.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632222.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632223.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632224.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632225.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632226.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632227.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632228.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632229.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632230.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632231.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632232.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632233.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632234.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632235.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632236.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632237.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632238.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632239.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632240.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632241.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632242.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632243.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632244.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632245.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632246.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632247.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632248.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632249.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632250.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632251.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632252.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632253.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632254.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632255.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632256.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632257.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632258.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632259.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632260.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632261.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632262.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632263.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632264.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632265.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632266.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632267.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632268.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632269.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632270.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632271.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632272.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632273.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632274.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632275.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225538.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225543.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225554.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2225555.csv
# Filtered content saved to: /content/drive/My Drive/Where In The World/Segmentation OUTPUT/2632209.csv
